# %% [markdown]
# <a href="https://colab.research.google.com/github/khonshu1102/Big-Data-Analytics/blob/main/MultipleRegression_Ass8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pandas as pd

# Read CSV file using relative path
data = pd.read_csv('multiple_regression_datsaset.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Hours Studied  10000 non-null  int64
#  1   Sleep Hours    10000 non-null  int64
#  2    Scores        10000 non-null  int64
# dtypes: int64(3)
# memory usage: 234.5 KB

# %%
data.head(10)
# Out:
#    Hours Studied  Sleep Hours   Scores
# 0              7            9       99
# 1              4            4       82
# 2              8            7       51
# 3              5            5       52
# 4              7            8       75
# 5              3            9       78
# 6              7            5       73
# 7              8            4       45
# 8              5            8       77
# 9              4            4       89

# %%
x=data.iloc[ :,0:1]
x
# Out:
#       Hours Studied
# 0                 7
# 1                 4
# 2                 8
# 3                 5
# 4                 7
# ...             ...
# 9995              1
# 9996              7
# 9997              6
# 9998              9
# 9999              7
#
# [10000 rows x 1 columns]

# %%
main=data.head(20)
main
# Out:
#     Hours Studied  Sleep Hours   Scores
# 0               7            9       99
# 1               4            4       82
# 2               8            7       51
# 3               5            5       52
# 4               7            8       75
# 5               3            9       78
# 6               7            5       73
# 7               8            4       45
# 8               5            8       77
# 9               4            4       89
# 10              8            4       91
# 11              8            6       79
# 12              3            9       47
# 13              6            4       47
# 14              5            7       79
# 15              2            4       72
# 16              8            8       73
# 17              6            7       83
# 18              2            4       54
# 19              5            7       75

# %%
main.shape
# Out:
# (20, 3)

# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\aradh\appdata\local\programs\python\python311\lib\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\aradh\appdata\local\programs\python\python311\lib\site-packages (from missingno) (1.26.3)
# Requirement already satisfied: matplotlib in c:\users\aradh\appdata\local\programs\python\python311\lib\site-packages (from missingno) (3.8.2)
# Requirement already satisfied: scipy in c:\users\aradh\appdata\local\programs\python\python311\lib\site-packages (from missingno) (1.13.0)
# Requirement already satisfied: seaborn in c:\users\aradh\appdata\local\programs\python\python311\lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aradh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\aradh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aradh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aradh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\aradh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\aradh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aradh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aradh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\aradh\appdata\local\programs\python\python311\lib\site-packages (from seaborn->missingno) (2.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aradh\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aradh\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\aradh\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import missingno as msn
msn.bar(main)
# Out:
# <Axes: >

# %%
x=main[' Scores']
x
# Out:
# 0     99
# 1     82
# 2     51
# 3     52
# 4     75
# 5     78
# 6     73
# 7     45
# 8     77
# 9     89
# 10    91
# 11    79
# 12    47
# 13    47
# 14    79
# 15    72
# 16    73
# 17    83
# 18    54
# 19    75
# Name:  Scores, dtype: int64

# %%
y=main.iloc[ :,0:3]
y
# Out:
#     Hours Studied  Sleep Hours   Scores
# 0               7            9       99
# 1               4            4       82
# 2               8            7       51
# 3               5            5       52
# 4               7            8       75
# 5               3            9       78
# 6               7            5       73
# 7               8            4       45
# 8               5            8       77
# 9               4            4       89
# 10              8            4       91
# 11              8            6       79
# 12              3            9       47
# 13              6            4       47
# 14              5            7       79
# 15              2            4       72
# 16              8            8       73
# 17              6            7       83
# 18              2            4       54
# 19              5            7       75

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=78)

# %%
# Assuming 'Hours Studied', 'Sleep Hours' are the independent variables (features)
# and 'Scores' is the dependent variable (target)

X = main[['Hours Studied', 'Sleep Hours']]  # Independent variables
y = main[' Scores']  # Dependent variable

# %%
print(main.columns)
# Out:
# Index(['Hours Studied', 'Sleep Hours', ' Scores'], dtype='object')

# %% [raw]
# model=LinearRegression()

# %%
model=LinearRegression()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Predict on the testing data
y_pred = model.predict(X_test)

# Calculate R-squared score
r_squared = model.score(X_test, y_test)
print("R-squared:", r_squared)
# Out:
# R-squared: 0.3059611166339299

# %%
import numpy as np
import pandas as pd

# Assuming 'main' is your DataFrame
# Randomly select 80% of indices
keep_indices = np.random.choice(main.index, int(len(main) * 0.8), replace=False)

# Create a DataFrame with 80% of the data
train_data = main.loc[keep_indices]

# Create a DataFrame with the remaining 20% of the data
test_data = main.drop(keep_indices)

# Separate features and target variable for training and testing data
X_train = train_data[['Hours Studied', 'Sleep Hours']]  # Independent variables for training
y_train = train_data[' Scores']  # Dependent variable for training

X_test = test_data[['Hours Studied', 'Sleep Hours']]  # Independent variables for testing
y_test = test_data[' Scores']  # Dependent variable for testing

# %%
y_pred
# Out:
# array([72.3657387 , 81.36850374, 66.75026708, 77.22371646])

# %%
test_data
# Out:
#     Hours Studied  Sleep Hours   Scores
# 1               4            4       82
# 6               7            5       73
# 12              3            9       47
# 17              6            7       83

# %%
train_data
# Out:
#     Hours Studied  Sleep Hours   Scores
# 14              5            7       79
# 4               7            8       75
# 11              8            6       79
# 0               7            9       99
# 7               8            4       45
# 16              8            8       73
# 19              5            7       75
# 18              2            4       54
# 15              2            4       72
# 10              8            4       91
# 9               4            4       89
# 5               3            9       78
# 3               5            5       52
# 13              6            4       47
# 8               5            8       77
# 2               8            7       51

# %%
# Convert y_pred and y_test to DataFrames for easier comparison and printing
df_results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

# Print the first few rows to see the comparison
print(df_results.head())
# Out:
#     Actual  Predicted
# 1       82  72.365739
# 6       73  81.368504
# 12      47  66.750267
# 17      83  77.223716
